# %%
import pandas as pd
import numpy as np
df=pd.read_csv("ToyotaCorolla - MLR.csv")
df
# Out:
#       Price  Age_08_04     KM Fuel_Type   HP  Automatic    cc  Doors  \
# 0     13500         23  46986    Diesel   90          0  2000      3
# 1     13750         23  72937    Diesel   90          0  2000      3
# 2     13950         24  41711    Diesel   90          0  2000      3
# 3     14950         26  48000    Diesel   90          0  2000      3
# 4     13750         30  38500    Diesel   90          0  2000      3
# ...     ...        ...    ...       ...  ...        ...   ...    ...
# 1431   7500         69  20544    Petrol   86          0  1300      3
# 1432  10845         72  19000    Petrol   86          0  1300      3
# 1433   8500         71  17016    Petrol   86          0  1300      3
# 1434   7250         70  16916    Petrol   86          0  1300      3
# 1435   6950         76      1    Petrol  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# 1             4      5    1165
# 2             4      5    1165
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age_08_04  1436 non-null   int64
#  2   KM         1436 non-null   int64
#  3   Fuel_Type  1436 non-null   object
#  4   HP         1436 non-null   int64
#  5   Automatic  1436 non-null   int64
#  6   cc         1436 non-null   int64
#  7   Doors      1436 non-null   int64
#  8   Cylinders  1436 non-null   int64
#  9   Gears      1436 non-null   int64
#  10  Weight     1436 non-null   int64
# dtypes: int64(10), object(1)
# memory usage: 123.5+ KB

# %%
Y=df["Price"]
Y
# Out:
# 0       13500
# 1       13750
# 2       13950
# 3       14950
# 4       13750
#         ...
# 1431     7500
# 1432    10845
# 1433     8500
# 1434     7250
# 1435     6950
# Name: Price, Length: 1436, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Price'],df["Age_08_04"])
plt.show()

# %%
df["Age_08_04"].hist()
print(df["Age_08_04"].skew())
# Out:
# -0.82670187309842

# %%
#boxplot
import matplotlib.pyplot as plt
plt.boxplot(df['Age_08_04'],vert= False)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Price'],df["KM"])
plt.show()

# %%
df["KM"].hist()
print(df["KM"].skew())
# Out:
# 1.0159121980877577

# %%
#boxplot
import matplotlib.pyplot as plt
plt.boxplot(df['KM'],vert= False)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Price'],df["Fuel_Type"])
plt.show()

# %%
df["Fuel_Type"].hist()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Price'],df["HP"])
plt.show()

# %%
df["HP"].hist()
print(df["HP"].skew())
# Out:
# 0.9558356472519488

# %%
#boxplot
import matplotlib.pyplot as plt
plt.boxplot(df['HP'],vert= False)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Price'],df["Automatic"])
plt.show()

# %%
df["Automatic"].hist()
print(df["Automatic"].skew())
# Out:
# 3.878196903617749

# %%
#boxplot
import matplotlib.pyplot as plt
plt.boxplot(df['Automatic'],vert= False)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Price'],df["cc"])
plt.show()

# %%
df["cc"].hist()
print(df["cc"].skew())
# Out:
# 27.431792795981686

# %%
#boxplot
import matplotlib.pyplot as plt
plt.boxplot(df['cc'],vert= False)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Price'],df["Doors"])
plt.show()

# %%
df["Doors"].hist()
print(df["Doors"].skew())
# Out:
# -0.07639499290452467

# %%
#boxplot
import matplotlib.pyplot as plt
plt.boxplot(df['Doors'],vert= False)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Price'],df["Cylinders"])
plt.show()

# %%
df["Cylinders"].hist()
print(df["Cylinders"].skew())
# Out:
# 0

# %%
#boxplot
import matplotlib.pyplot as plt
plt.boxplot(df['Cylinders'],vert= False)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Price'],df["Gears"])
plt.show()

# %%
df["Gears"].hist()
print(df["Gears"].skew())
# Out:
# 2.283959738160194

# %%
#boxplot
import matplotlib.pyplot as plt
plt.boxplot(df['Gears'],vert= False)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Price'],df["Weight"])
plt.show()

# %%
df["Weight"].hist()
print(df["Weight"].skew())
# Out:
# 3.108639394626062

# %%
#boxplot
import matplotlib.pyplot as plt
plt.boxplot(df['Weight'],vert= False)
plt.show()

# %%
df.corr()
# Out:
#               Price  Age_08_04        KM        HP  Automatic        cc  \
# Price      1.000000  -0.876590 -0.569960  0.314990   0.033081  0.126389
# Age_08_04 -0.876590   1.000000  0.505672 -0.156622   0.031717 -0.098084
# KM        -0.569960   0.505672  1.000000 -0.333538  -0.081854  0.102683
# HP         0.314990  -0.156622 -0.333538  1.000000   0.013144  0.035856
# Automatic  0.033081   0.031717 -0.081854  0.013144   1.000000  0.066740
# cc         0.126389  -0.098084  0.102683  0.035856   0.066740  1.000000
# Doors      0.185326  -0.148359 -0.036197  0.092424  -0.027654  0.079903
# Cylinders       NaN        NaN       NaN       NaN        NaN       NaN
# Gears      0.063104  -0.005364  0.015023  0.209477  -0.098555  0.014629
# Weight     0.581198  -0.470253 -0.028598  0.089614   0.057249  0.335637
#
#               Doors  Cylinders     Gears    Weight
# Price      0.185326        NaN  0.063104  0.581198
# Age_08_04 -0.148359        NaN -0.005364 -0.470253
# ...

# %%
Y=df["Price"]
X=df[["Age_08_04"]]

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()

# %%
LR.fit(X,Y)
# Out:
# LinearRegression()

# %%
Y_pred=LR.predict(X)
Y_pred
# Out:
# array([16362.58619364, 16362.58619364, 16191.65260863, ...,
#         8157.77411309,  8328.7076981 ,  7303.10618803])

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
mse=mean_squared_error(Y,Y_pred)
#np.round(mse,2)
print("MSE:",mse)
print("rmse:",np.sqrt(mse))
r2score=r2_score(Y,Y_pred)
print("r score:",r2score)
# Out:
# MSE: 3044403.458963609
# rmse: 1744.821898923672
# r score: 0.7684108996825327

# %%
Y=df['Price']
X1=df[['Age_08_04','Weight']]

# %%
LR.fit(X1,Y)
# Out:
# LinearRegression()

# %%
Y1_pred=LR.predict(X1)
Y1_pred
# Out:
# array([17090.43153785, 17090.43153785, 16939.3924226 , ...,
#         7598.32776914,  7749.36688439,  8323.00150896])

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
mse=mean_squared_error(Y,Y1_pred)
#np.round(mse,2)
print("MSE:",mse)
print("rmse:",np.sqrt(mse))
r2score=r2_score(Y,Y1_pred)
print("r score:",r2score)
# Out:
# MSE: 2562472.821411396
# rmse: 1600.7725701708523
# r score: 0.8050715736932419

# %%
Y=df['Price']
X2=df[['Age_08_04','Weight','KM']]

# %%
LR.fit(X2,Y)
# Out:
# LinearRegression()

# %%
Y2_pred=LR.predict(X2)
Y2_pred
# Out:
# array([17024.410447  , 16396.84005466, 17031.7540617 , ...,
#         9042.14905478,  9164.78851814, 10790.54350568])

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
mse=mean_squared_error(Y,Y2_pred)
#np.round(mse,2)
print("MSE:",mse)
print("rmse:",np.sqrt(mse))
r2score=r2_score(Y,Y2_pred)
print("r score:",r2score)
# Out:
# MSE: 1996777.7613788072
# rmse: 1413.0738697530314
# r score: 0.848104243893788

# %%
Y=df['Price']
X3=df[['Age_08_04','Weight','KM']]

# %%
LR.fit(X3,Y)
# Out:
# LinearRegression()

# %%
Y3_pred=LR.predict(X3)
Y3_pred
# Out:
# array([17024.410447  , 16396.84005466, 17031.7540617 , ...,
#         9042.14905478,  9164.78851814, 10790.54350568])

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
mse=mean_squared_error(Y,Y3_pred)
#np.round(mse,2)
print("MSE:",mse)
print("rmse:",np.sqrt(mse))
r2score=r2_score(Y,Y3_pred)
print("r score:",r2score)
# Out:
# MSE: 1996777.7613788072
# rmse: 1413.0738697530314
# r score: 0.848104243893788

# %%
import statsmodels.formula.api as smf
model=smf.ols('Price~Age_08_04+Weight+KM',data=df).fit()
model.summary() #MODEL 1
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.848
# Model:                            OLS   Adj. R-squared:                  0.848
# Method:                 Least Squares   F-statistic:                     2665.
# Date:                Wed, 25 Sep 2024   Prob (F-statistic):               0.00
# Time:                        11:56:38   Log-Likelihood:                -12454.
# No. Observations:                1436   AIC:                         2.492e+04
# Df Residuals:                    1432   BIC:                         2.494e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1880.3356    962.718     -1.953      0.051   -3768.825       8.153
# ...

# %%
import statsmodels.formula.api as smf
model=smf.ols('Price~Age_08_04+Weight',data=df).fit()
model.summary() #MODEL 2
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.805
# Model:                            OLS   Adj. R-squared:                  0.805
# Method:                 Least Squares   F-statistic:                     2959.
# Date:                Wed, 25 Sep 2024   Prob (F-statistic):               0.00
# Time:                        11:56:38   Log-Likelihood:                -12633.
# No. Observations:                1436   AIC:                         2.527e+04
# Df Residuals:                    1433   BIC:                         2.529e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3149.7074   1052.897      2.991      0.003    1084.324    5215.091
# ...

# %%
import statsmodels.formula.api as smf
model=smf.ols('Price~Age_08_04+HP',data=df).fit()
model.summary() #MODEL 3
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.801
# Model:                            OLS   Adj. R-squared:                  0.801
# Method:                 Least Squares   F-statistic:                     2880.
# Date:                Wed, 25 Sep 2024   Prob (F-statistic):               0.00
# Time:                        11:56:38   Log-Likelihood:                -12648.
# No. Observations:                1436   AIC:                         2.530e+04
# Df Residuals:                    1433   BIC:                         2.532e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.551e+04    341.793     45.367      0.000    1.48e+04    1.62e+04
# ...

# %%
#modelfitting 
model=smf.ols('Age_08_04~HP',data=df).fit()
R2=model.rsquared
VIF=1/(1-R2)
print("VIF Value:",VIF)
# Out:
# VIF Value: 1.0251473326599274

# %%
# Residual Analysis
model = smf.ols('Price~Age_08_04+HP',data=df).fit()
model.summary()

df['Price'] # y actual
model.fittedvalues # y pred

print(model.resid) # y - ypred


model.resid.hist()
# Out:
# 0      -2172.011690
# 1      -1922.011690
# 2      -1556.641610
# 3       -225.901451
# 4       -764.421132
#            ...
# 1431    -388.577198
# 1432    3452.533041
# 1433     942.162961
# 1434    -473.207118
# 1435    -839.451621
# Length: 1436, dtype: float64
# <AxesSubplot:>

# %%
## Test for Normality of Residuals (Q-Q Plot)
import matplotlib.pyplot as plt
import statsmodels.api as sm
qqplot=sm.qqplot(model.resid,line='q') # line = 45 to draw the diagnoal line
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
# model deletion dignositics


model_influence = model.get_influence()
(cooks, pvalue) = model_influence.cooks_distance
cooks
# Out:
# array([2.21129382e-03, 1.73154660e-03, 1.09106934e-03, ...,
#        1.97071818e-04, 4.83488983e-05, 1.70116895e-04])

# %%
import numpy as np
import matplotlib.pyplot as plt
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(df)), np.round(cooks, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
# higly influence points
k = 2
n = len(df)
leverage_cutoff = 3*((k + 1)/n)
leverage_cutoff
# Out:
# 0.00626740947075209

# %%
# points which are greater than leverage value treated as influencer observations

df[cooks>leverage_cutoff]

df.drop([70,76,78,79],inplace=True)
df.shape
# Out:
# (1432, 11)

# %%
model = smf.ols('Price~Age_08_04+HP',data=df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.800
# Model:                            OLS   Adj. R-squared:                  0.800
# Method:                 Least Squares   F-statistic:                     2858.
# Date:                Wed, 25 Sep 2024   Prob (F-statistic):               0.00
# Time:                        11:56:41   Log-Likelihood:                -12612.
# No. Observations:                1432   AIC:                         2.523e+04
# Df Residuals:                    1429   BIC:                         2.525e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.549e+04    341.942     45.306      0.000    1.48e+04    1.62e+04
# ...

# %%
Y=df["Price"]
X=df[["Age_08_04","HP"]]

# %%
# data partition
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test  = train_test_split(X,Y, test_size=0.2)

# %%
from sklearn.linear_model import Lasso, Ridge
from sklearn.preprocessing import StandardScaler

# %%
# Standardizing the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
coef_sm = model.params
print("Statsmodels coefficients:", coef_sm)

# Apply Lasso Regression
lasso = Lasso(alpha=1.0)
lasso.fit(X_train_scaled, Y_train)
print("Lasso coefficients:", lasso.coef_)

# Apply Ridge Regression
ridge = Ridge(alpha=1.0)
ridge.fit(X_train_scaled, Y_train)
print("Ridge coefficients:", ridge.coef_)
# Out:
# Statsmodels coefficients: Intercept    15491.865073
# Age_08_04     -165.076982
# HP              44.043565
# dtype: float64
# Lasso coefficients: [-3105.3053814    587.56883668]
# Ridge coefficients: [-3103.49426823   588.3022839 ]

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Create a Ridge regression model
ridge_model = Ridge(alpha=1.0)  # alpha is the regularization strength
ridge_model.fit(X, Y)

# Predicting using Ridge model
y_pred_ridge = ridge_model.predict(X)

# Evaluating the Ridge model performance
mse_ridge = mean_squared_error(Y, y_pred_ridge)
rmse_ridge = np.sqrt(mse_ridge)
r2_ridge = r2_score(Y, y_pred_ridge)

print("Ridge Regression:")
print("Root Mean Squared Error (RMSE):", np.round(rmse_ridge, 5))
print("R2 Score:", np.round(r2_ridge, 5))
# Out:
# Ridge Regression:
# Root Mean Squared Error (RMSE): 1617.34602
# R2 Score: 0.80001

# %% [markdown]
# ###interview questions
#
# Normalization and standardization are two techniques used to preprocess data, especially when working with machine learning algorithms that are sensitive to the scale of the data.
#
# Normalization scales the data in between the range 0 to 1. Useful when the distribution of data is not Gaussian and when different features have different ranges. It helps improve convergence in algorithms like gradient descent.
#
# Standardization scales the data in between the range -3 to +3 and also deletes the units from the data. Particularly helpful when the data follows a Gaussian distribution. Many algorithms (like PCA, logistic regression, and SVM) assume that the data is centered around zero.
#
#
# Multicollinearity occurs when independent variables in a regression model are highly correlated, which can make the estimation of coefficients unstable and inflate standard errors. Here are some techniques to address multicollinearity:
#
# --->correlation
# --->Regularization
# --->PCA
